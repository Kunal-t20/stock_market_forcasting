# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\Projects\Stock_analysis\data\APPL.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\KUNAL\AppData\Local\Temp\ipykernel_16800\3610124019.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df=pd.read_csv('D:\Projects\Stock_analysis\data\APPL.csv')

# %%
df.head()
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker                AAPL                AAPL                AAPL
# 1        Date                 NaN                 NaN                 NaN
# 2  2015-01-02  24.261045455932617  24.729268449277928  23.821669706907244
# 3  2015-01-05  23.577573776245117  24.110149898969926  23.391173064448488
# 4  2015-01-06  23.579797744750977  23.839428081950576   23.21808887323788
#
#                  Open     Volume
# 0                AAPL       AAPL
# 1                 NaN        NaN
# 2   24.71817244368647  212818400
# 3  24.030263395910563  257142000
# 4   23.64193132701962  263188400

# %%
df=df[['Close']].copy()
df=df.dropna()
df.head()
# Out:
#                                             Close
# 1970-01-01 00:00:00.000000000                AAPL
# 1970-01-01 00:00:00.000000002  24.261045455932617
# 1970-01-01 00:00:00.000000003  23.577573776245117
# 1970-01-01 00:00:00.000000004  23.579797744750977
# 1970-01-01 00:00:00.000000005  23.910438537597656

# %%
df.index = pd.to_datetime(df.index)
df_arima = df.copy()

# %%
df_reset = df.reset_index()
df_prophet = df_reset.rename(columns={'Date': 'ds', 'Close': 'y'})

df_prophet
# Out:
#                              index                   y
# 0    1970-01-01 00:00:00.000000000                AAPL
# 1    1970-01-01 00:00:00.000000002  24.261045455932617
# 2    1970-01-01 00:00:00.000000003  23.577573776245117
# 3    1970-01-01 00:00:00.000000004  23.579797744750977
# 4    1970-01-01 00:00:00.000000005  23.910438537597656
# ...                            ...                 ...
# 2512 1970-01-01 00:00:00.000002513   257.2866516113281
# 2513 1970-01-01 00:00:00.000002514   258.1037292480469
# 2514 1970-01-01 00:00:00.000002515  254.68588256835938
# 2515 1970-01-01 00:00:00.000002516  251.30787658691406
# 2516 1970-01-01 00:00:00.000002517      249.5341796875
#
# [2517 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_arima.index, df_arima['Close'])
plt.title('Stock Price (Closing)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
